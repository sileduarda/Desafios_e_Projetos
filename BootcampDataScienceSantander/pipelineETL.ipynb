# %% [markdown]
# ### Extract
# Criando uma lista de IDs de usuários a partir do arquivo csv.
# Para cada ID, faremos uma requisição à API para obter os detalhes do usuário.

# %%
user = [{
    'id' : 1, 'name' : 'Maria Eduarda', 'news' : ' ' },
    {'id' : 2, 'name': 'Paulo Gonçalves', 'news': ' ' }
]

# %%
import pandas as pd 
users = pd.DataFrame(user)
users.head()
